# %%
from inference import inference
import matplotlib.pyplot as plt

# %% [markdown]
# # demo of prediction with the trained model

# %%
files = ["assets/example_images/cat.jpg", "assets/example_images/dog.jpg"] # or insert your own image paths here
for file in files:
    predicted_label, original_image, probabilities = inference.inference_image(file)
    plt.imshow(original_image)
    plt.title(f"Predicted: {predicted_label}")
    plt.axis('off')
    plt.show()
